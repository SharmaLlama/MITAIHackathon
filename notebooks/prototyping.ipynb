# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 97.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 126.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless━━━━━━━━━━━━━━━━━━━━ 1/6 [pillow-heif]
#     Found existing installation: opencv-python-headless 4.11.0.86m 1/6 [pillow-heif]
#     Uninstalling opencv-python-headless-4.11.0.86:━━━━━━━━━━━━ 1/6 [pillow-heif]
#       Successfully uninstalled opencv-python-headless-4.11.0.86 1/6 [pillow-heif]
#   Attempting uninstall: idna0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/6 [opencv-python-headless]
#     Found existing installation: idna 3.10━━━━━━━━━━━━━━━━━━━━ 2/6 [opencv-python-headless]
#     Uninstalling idna-3.10:━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/6 [opencv-python-headless]
#       Successfully uninstalled idna-3.10━━━━━━━━━━━━━━━━━━━━━━ 2/6 [opencv-python-headless]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [roboflow]5/6 [roboflow]-headless]
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="S81BnkOmGJ78xeYKxKIX")
project = rf.workspace("andrei-dore-5lz05").project("acne04")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to acne04-1 in yolov11:: 100%|██████████| 2850/2850 [00:05<00:00, 553.68it/s]

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11s.pt")

# %%
# import os

# # Path to the folder containing the text files
# folder_path = "../data/acne04-1/valid/labels/"

# # Iterate through all files in the folder
# for filename in os.listdir(folder_path):
#     if filename.startswith("levle") and filename.endswith(".txt"):
#         print(filename)
#         # Extract the level number (X) from the filename
#         level_number = int(filename.split('_')[0].replace("levle", ""))
        
#         # Full path to the file
#         file_path = os.path.join(folder_path, filename)
        
#         # Read the file and process its content
#         with open(file_path, 'r') as file:
#             lines = file.readlines()
        
#         # Modify the lines
#         modified_lines = []
#         for line in lines:
#             parts = line.split()
#             if parts:  # Ensure the line is not empty
#                 parts[0] = str(level_number)  # Replace the 0th element with X
#                 modified_lines.append(" ".join(parts))
        
#         # Write the modified lines back to the file
#         with open(file_path, 'w') as file:
#             file.write("\n".join(modified_lines))

# %%
result = model.train(data="/home/ubuntu/MITAIHackathon/data/acne04-1/data.yaml", epochs=20, imgsz=1504, batch=4, workers=2, close_mosaic=0, name="yolov11m_acne04")
# Out:
# Ultralytics 8.3.124 🚀 Python-3.10.17 torch-2.7.0+cu126 CUDA:0 (Tesla T4, 14914MiB)
# ...
